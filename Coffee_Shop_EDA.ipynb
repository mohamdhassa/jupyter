# %% [markdown]
# # Coffee Shop - EDA

# %%
import pandas as pd

# %%
print("\033[1;36;48m Reading a '.csv' file into a DataFrame")
# Read csv file from and URL (web) Link
# .read_csv is a function that reads csv or any other delimited files
df_coffee_sales = pd.read_csv('https://raw.githubusercontent.com/JubJT/data_rep/main/coffee_shop.csv')
# Out:
#  Reading a '.csv' file into a DataFrame

# %%
# reading file form laptop

# %%
# Displays the top 5 rows

# %%
df_coffee_sales.head(100)

df_coffee_sales.tail(50)
# Out:
#       transaction_date transaction_time  customer_id  quantity  \
# 49844       2019-04-11         19:48:27          NaN         1
# 49845       2019-04-11         10:17:50          NaN         1
# 49846       2019-04-12         07:16:09          NaN         1
# 49847       2019-04-12         10:22:15          NaN         1
# 49848       2019-04-12         13:45:16       8455.0         1
# 49849       2019-04-12         13:42:27       8115.0         1
# 49850       2019-04-13         08:06:45       8158.0         1
# 49851       2019-04-13         14:57:05       8147.0         1
# 49852       2019-04-14         09:43:36          NaN         1
# 49853       2019-04-14         08:13:22       8189.0         1
# 49854       2019-04-14         09:30:34       8392.0         1
# 49855       2019-04-14         17:25:21          NaN         1
# 49856       2019-04-14         16:05:40          NaN         1
# 49857       2019-04-15         09:17:40        718.0         1
# ...

# %%
# Print the number of columns & number of rows

df_coffee_sales.shape
# Out:
# (49894, 13)

# %%
# Print the column names 

df_coffee_sales.columns.to_list()
# Out:
# ['transaction_date',
#  'transaction_time',
#  'customer_id',
#  'quantity',
#  'line_item_amount',
#  'unit_price',
#  'product_group',
#  'product_category',
#  'product_type',
#  'current_wholesale_price',
#  'customer_since',
#  'customer_birth_year',
#  'customer_generation']

# %%
# What type of data type does our columns contain
df_coffee_sales.dtypes
# Out:
# transaction_date            object
# transaction_time            object
# customer_id                float64
# quantity                     int64
# line_item_amount           float64
# unit_price                 float64
# product_group               object
# product_category            object
# product_type                object
# current_wholesale_price    float64
# customer_since              object
# customer_birth_year        float64
# customer_generation         object
# dtype: object

# %%
#adjust data types
df_coffee_sales['transaction_date'] = pd.to_datetime(df_coffee_sales['transaction_date'])
df_coffee_sales['customer_since'] = pd.to_datetime(df_coffee_sales['customer_since'])
# df_coffee_sales['transaction_date']

df_coffee_sales.dtypes
# Out:
# transaction_date           datetime64[ns]
# transaction_time                   object
# customer_id                       float64
# quantity                            int64
# line_item_amount                  float64
# unit_price                        float64
# product_group                      object
# product_category                   object
# product_type                       object
# current_wholesale_price           float64
# customer_since             datetime64[ns]
# customer_birth_year               float64
# customer_generation                object
# dtype: object

# %%
#df_coffee_sales['transaction_time'] = df_coffee_sales['transaction_date'].astype("str")+' '+df_coffee_sales['transaction_time']
df_coffee_sales.head()
# Out:
#   transaction_date transaction_time  customer_id  quantity  line_item_amount  \
# 0       2019-04-01         12:04:43        558.0         1               2.5
# 1       2019-04-01         11:15:38         22.0         1               2.5
# 2       2019-04-01         12:05:31        659.0         2               5.0
# 3       2019-04-01         16:49:38        407.0         1               2.5
# 4       2019-04-01         19:17:34        537.0         2               5.0
#
#    unit_price product_group product_category     product_type  \
# 0         2.5     Beverages              Tea  Brewed Chai tea
# 1         2.5     Beverages              Tea  Brewed Chai tea
# 2         2.5     Beverages              Tea  Brewed Chai tea
# 3         2.5     Beverages              Tea  Brewed Chai tea
# 4         2.5     Beverages              Tea  Brewed Chai tea
#
#    current_wholesale_price customer_since  customer_birth_year  \
# ...

# %%
df_coffee_sales['customer_since'] = pd.to_datetime(df_coffee_sales['customer_since'])
# df_coffee_sales['transaction_date']
df_coffee_sales['transaction_time']= pd.to_datetime(df_coffee_sales['transaction_time'])

df_coffee_sales.dtypes
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5852\997263248.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_coffee_sales['transaction_time']= pd.to_datetime(df_coffee_sales['transaction_time'])
# transaction_date           datetime64[ns]
# transaction_time           datetime64[ns]
# customer_id                       float64
# quantity                            int64
# line_item_amount                  float64
# unit_price                        float64
# product_group                      object
# product_category                   object
# product_type                       object
# current_wholesale_price           float64
# customer_since             datetime64[ns]
# customer_birth_year               float64
# customer_generation                object
# dtype: object

# %%
#convert customer_id to str 
df_coffee_sales['customer_id'] = df_coffee_sales['customer_id'].astype('str')
df_coffee_sales['customer_birth_year'].astype('int')

df_coffee_sales['customer_birth_year'].isna().sum() 

# convert null tovalu

df_coffee_sales['customer_birth_year']=df_coffee_sales['customer_birth_year'].fillna(0)
df_coffee_sales['customer_birth_year']=df_coffee_sales['customer_birth_year'].astype('int')

df_coffee_sales['customer_birth_year'].isna().sum() 
df_coffee_sales.dtypes
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[256], line 3
#       1 #convert customer_id to str
#       2 df_coffee_sales['customer_id'] = df_coffee_sales['customer_id'].astype('str')
# ----> 3 df_coffee_sales['customer_birth_year'].astype('int')
#       5 df_coffee_sales['customer_birth_year'].isna().sum()
#       7 # convert null tovalu
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
# ...

# %%
# Change the column names:
# --> 'line_item_amount' to 'retail price'


df_coffee_sales=df_coffee_sales.rename(columns={'retil price':'retil_price'})
df_coffee_sales.head()
# Out:
#   transaction_date    transaction_time customer_id  quantity  retil_price  \
# 0       2019-04-01 2019-04-01 12:04:43       558.0         1          2.5
# 1       2019-04-01 2019-04-01 11:15:38        22.0         1          2.5
# 2       2019-04-01 2019-04-01 12:05:31       659.0         2          5.0
# 3       2019-04-01 2019-04-01 16:49:38       407.0         1          2.5
# 4       2019-04-01 2019-04-01 19:17:34       537.0         2          5.0
#
#    unit_price product_group product_category     product_type  \
# 0         2.5     Beverages              Tea  Brewed Chai tea
# 1         2.5     Beverages              Tea  Brewed Chai tea
# 2         2.5     Beverages              Tea  Brewed Chai tea
# 3         2.5     Beverages              Tea  Brewed Chai tea
# 4         2.5     Beverages              Tea  Brewed Chai tea
#
#    current_wholesale_price customer_since  customer_birth_year  \
# 0                     0.63     2018-06-19                 1983
# ...

# %%
df_coffee_sales.transaction_time
df_coffee_sales['retil_price']
# Out:
# 0        2.50
# 1        2.50
# 2        5.00
# 3        2.50
# 4        5.00
#          ...
# 49889    8.95
# 49890    8.95
# 49891    8.95
# 49892    8.95
# 49893    8.95
# Name: retil_price, Length: 49894, dtype: float64

# %%
# Create a New column to calculate:
# --> 'total_wholesale_price' = current_wholesale_price * quantity
df_coffee_sales['total_wholesale_price'] = df_coffee_sales['current_wholesale_price']*df_coffee_sales['quantity']
df_coffee_sales.head()
# --> 'profit' = retail price - current_wholesale_price

df_coffee_sales['profit'] = df_coffee_sales['retil_price']- df_coffee_sales['current_wholesale_price']
df_coffee_sales.head()
# Out:
#   transaction_date    transaction_time customer_id  quantity  retil_price  \
# 0       2019-04-01 2019-04-01 12:04:43       558.0         1          2.5
# 1       2019-04-01 2019-04-01 11:15:38        22.0         1          2.5
# 2       2019-04-01 2019-04-01 12:05:31       659.0         2          5.0
# 3       2019-04-01 2019-04-01 16:49:38       407.0         1          2.5
# 4       2019-04-01 2019-04-01 19:17:34       537.0         2          5.0
#
#    unit_price product_group product_category     product_type  \
# 0         2.5     Beverages              Tea  Brewed Chai tea
# 1         2.5     Beverages              Tea  Brewed Chai tea
# 2         2.5     Beverages              Tea  Brewed Chai tea
# 3         2.5     Beverages              Tea  Brewed Chai tea
# 4         2.5     Beverages              Tea  Brewed Chai tea
#
#    current_wholesale_price customer_since  customer_birth_year  \
# 0                     0.63     2018-06-19                 1983
# ...

# %%
df_coffee_sales.columns.to_list()
# Out:
# ['transaction_date',
#  'transaction_time',
#  'customer_id',
#  'quantity',
#  'retil_price',
#  'unit_price',
#  'product_group',
#  'product_category',
#  'product_type',
#  'current_wholesale_price',
#  'customer_since',
#  'customer_birth_year',
#  'customer_generation',
#  'total_wholesale_price',
#  'profit']

# %%
col_order=['transaction_date',
 'transaction_time',
 'customer_id',
 'quantity',
 'retil_price',
 'unit_price',
 'profit',
  'current_wholesale_price',
 'product_group',
 'product_category',
 'product_type',
 'customer_since',
 'customer_birth_year',
 'customer_generation',
 'total_wholesale_price']

# %%
df_coffee_sales[col_order].head()
# Out:
#   transaction_date    transaction_time customer_id  quantity  retil_price  \
# 0       2019-04-01 2019-04-01 12:04:43       558.0         1          2.5
# 1       2019-04-01 2019-04-01 11:15:38        22.0         1          2.5
# 2       2019-04-01 2019-04-01 12:05:31       659.0         2          5.0
# 3       2019-04-01 2019-04-01 16:49:38       407.0         1          2.5
# 4       2019-04-01 2019-04-01 19:17:34       537.0         2          5.0
#
#    unit_price  profit  current_wholesale_price product_group product_category  \
# 0         2.5    1.87                     0.63     Beverages              Tea
# 1         2.5    1.87                     0.63     Beverages              Tea
# 2         2.5    4.37                     0.63     Beverages              Tea
# 3         2.5    1.87                     0.63     Beverages              Tea
# 4         2.5    4.37                     0.63     Beverages              Tea
#
# ...

# %%
# How many NULL values do we have in each column

df_coffee_sales.isna().sum()/df_coffee_sales.shape[0]*100
# Out:
# transaction_date            0.000000
# transaction_time            0.000000
# customer_id                 0.000000
# quantity                    0.000000
# retil_price                 0.000000
# unit_price                  0.000000
# product_group               0.000000
# product_category            0.000000
# product_type                0.000000
# current_wholesale_price     0.000000
# customer_since             50.190404
# customer_birth_year         0.000000
# customer_generation        50.190404
# total_wholesale_price       0.000000
# profit                      0.000000
# dtype: float64

# %%
df_coffee_sales[df_coffee_sales.isna()]

df_coffee_sales[df_coffee_sales.isna().any(axis=1)]
# Out:
#       transaction_date    transaction_time customer_id  quantity  retil_price  \
# 242         2019-04-07 2019-04-07 10:59:31         nan         2         5.00
# 243         2019-04-07 2019-04-07 08:27:02         nan         2         5.00
# 244         2019-04-07 2019-04-07 09:47:14         nan         2         5.00
# 247         2019-04-07 2019-04-07 10:50:54         nan         1         2.50
# 248         2019-04-07 2019-04-07 02:07:56         nan         1         2.50
# ...                ...                 ...         ...       ...          ...
# 49880       2019-04-20 2019-04-20 08:56:10         nan         1         8.95
# 49881       2019-04-20 2019-04-20 11:58:36         nan         1         8.95
# 49884       2019-04-21 2019-04-21 10:55:58         nan         1         8.95
# 49887       2019-04-24 2019-04-24 08:46:07         nan         1         8.95
# 49891       2019-04-25 2019-04-25 10:48:21         nan         1         8.95
#
# ...

# %%
# How many NULL values do we have in each column

# %%
# Do we have duplicated transactions?
df_coffee_sales.duplicated().sum()
# Out:
# 149

# %%
# Display the summary information
df_coffee_sales[df_coffee_sales.duplicated()].sort_values('transaction_time')
# Out:
#       transaction_date    transaction_time customer_id  quantity  retil_price  \
# 37655       2019-04-07 2019-04-07 07:00:50      5211.0         1         1.00
# 37657       2019-04-07 2019-04-07 08:06:36      5531.0         1         1.00
# 37683       2019-04-07 2019-04-07 08:53:22         nan         1         3.75
# 37675       2019-04-07 2019-04-07 09:31:48         nan         1         3.75
# 37661       2019-04-07 2019-04-07 10:10:26      5563.0         1         1.00
# ...                ...                 ...         ...       ...          ...
# 46069       2019-04-24 2019-04-24 19:28:47      8392.0         1         2.10
# 38468       2019-04-27 2019-04-27 08:56:42         nan         1         1.00
# 38469       2019-04-27 2019-04-27 08:56:42         nan         1         1.00
# 38483       2019-04-27 2019-04-27 09:06:24         nan         1         3.75
# 38485       2019-04-27 2019-04-27 09:49:35         nan         1         3.75
#
# ...

# %%
# What is the highest sales price (retail price)
df_coffee_sales['retil_price'].max()
# Out:
# 360.0

# %%
# What is the least profit
df_coffee_sales['profit'].min()
# Out:
# -6.0

# %%
# Display the summary statistics
df_coffee_sales.describe(include= 'all')
# Out:
#                      transaction_date               transaction_time  \
# count                           49894                          49894
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean    2019-04-15 01:16:35.855213056  2019-04-15 13:31:13.618952192
# min               2019-04-01 00:00:00            2019-04-01 07:01:20
# 25%               2019-04-08 00:00:00            2019-04-08 12:46:09
# 50%               2019-04-15 00:00:00            2019-04-15 11:56:55
# 75%               2019-04-22 00:00:00  2019-04-22 12:10:13.249999872
# max               2019-04-29 00:00:00            2019-04-29 19:59:28
# std                               NaN                            NaN
#
#        customer_id      quantity   retil_price    unit_price product_group  \
# ...

# %%
# Which customer_generation is the highest?

df_coffee_sales['customer_generation'].value_counts(dropna=False, normalize=True)
# Out:
# customer_generation
# NaN                    0.501904
# Baby Boomers           0.120636
# Gen X                  0.114062
# Older Millennials      0.109713
# Gen Z                  0.085962
# Younger Millennials    0.067724
# Name: proportion, dtype: float64

# %%
# How many product_category does the coffee shop offer? and which was bought the most?
df_coffee_sales['product_category'].value_counts()
# Out:
# product_category
# Coffee                19675
# Tea                   15135
# Bakery                 7616
# Drinking Chocolate     3836
# Flavours               2248
# Coffee beans            587
# Loose Tea               401
# Branded                 245
# Packaged Chocolate      151
# Name: count, dtype: int64

# %%
# How many non-member customers?

df_coffee_sales['customer_id'].replace("nan" ,None).isna().sum()
df_coffee_sales['customer_id'].value_counts()
# Out:
# customer_id
# nan       25033
# 8285.0       31
# 548.0        31
# 3.0          31
# 8341.0       29
#           ...
# 359.0         1
# 5076.0        1
# 5589.0        1
# 5784.0        1
# 427.0         1
# Name: count, Length: 2248, dtype: int64

# %%
# Bonus: Display all transactions with NULL values

# %%
coffe_category_qty_mask = (df_coffee_sales['product_category'] =='Coffee') & (df_coffee_sales['quantity']>1)
df_coffee_sales[coffe_category_qty_mask]
# Out:
#       transaction_date    transaction_time customer_id  quantity  retil_price  \
# 985         2019-04-01 2019-04-01 15:54:39       781.0         2          7.0
# 987         2019-04-01 2019-04-01 17:44:28       209.0         2          7.0
# 988         2019-04-01 2019-04-01 19:10:16       631.0         2          7.0
# 993         2019-04-01 2019-04-01 16:29:36       632.0         2          7.0
# 995         2019-04-01 2019-04-01 15:32:25      5033.0         2          7.0
# ...                ...                 ...         ...       ...          ...
# 46252       2019-04-29 2019-04-29 17:12:13         nan         2          4.2
# 46256       2019-04-29 2019-04-29 11:03:34      8348.0         2          6.0
# 46257       2019-04-29 2019-04-29 15:52:10         nan         2          4.2
# 46258       2019-04-29 2019-04-29 13:27:11         nan         2          4.2
# 46260       2019-04-29 2019-04-29 11:53:48      8431.0         2          6.0
#
# ...

# %%
df_coffee_sales[~coffe_category_qty_mask]
# Out:
#       transaction_date    transaction_time customer_id  quantity  retil_price  \
# 0           2019-04-01 2019-04-01 12:04:43       558.0         1         2.50
# 1           2019-04-01 2019-04-01 11:15:38        22.0         1         2.50
# 2           2019-04-01 2019-04-01 12:05:31       659.0         2         5.00
# 3           2019-04-01 2019-04-01 16:49:38       407.0         1         2.50
# 4           2019-04-01 2019-04-01 19:17:34       537.0         2         5.00
# ...                ...                 ...         ...       ...          ...
# 49889       2019-04-24 2019-04-24 09:31:54      8113.0         1         8.95
# 49890       2019-04-25 2019-04-25 06:17:12      5778.0         1         8.95
# 49891       2019-04-25 2019-04-25 10:48:21         nan         1         8.95
# 49892       2019-04-25 2019-04-25 08:54:27      8039.0         1         8.95
# 49893       2019-04-25 2019-04-25 14:32:27      8081.0         1         8.95
#
# ...

# %%
unprofitable_mask = df_coffee_sales['profit'] <=0
df_coffee_sales[unprofitable_mask]
# Out:
#       transaction_date    transaction_time customer_id  quantity  retil_price  \
# 37654       2019-04-07 2019-04-07 07:00:50      5211.0         1          1.0
# 37655       2019-04-07 2019-04-07 07:00:50      5211.0         1          1.0
# 37656       2019-04-07 2019-04-07 08:06:36      5531.0         1          1.0
# 37657       2019-04-07 2019-04-07 08:06:36      5531.0         1          1.0
# 37658       2019-04-07 2019-04-07 08:39:48      5736.0         1          1.0
# ...                ...                 ...         ...       ...          ...
# 45386       2019-04-26 2019-04-26 10:43:19      5235.0         3          0.0
# 45390       2019-04-26 2019-04-26 07:53:09         nan         1          0.0
# 45395       2019-04-26 2019-04-26 12:51:58      5180.0         3          0.0
# 46267       2019-04-07 2019-04-07 09:42:52      5033.0         1         12.0
# 46268       2019-04-07 2019-04-07 10:56:05      5656.0         1         12.0
#
# ...

# %%
query_coffee_cat = "product_category == 'Coffee'"

df_coffee_sales.query(query_coffee_cat)
# Out:
#       transaction_date    transaction_time customer_id  quantity  retil_price  \
# 985         2019-04-01 2019-04-01 15:54:39       781.0         2          7.0
# 986         2019-04-01 2019-04-01 18:49:48       128.0         1          3.5
# 987         2019-04-01 2019-04-01 17:44:28       209.0         2          7.0
# 988         2019-04-01 2019-04-01 19:10:16       631.0         2          7.0
# 989         2019-04-01 2019-04-01 15:01:50       355.0         1          3.5
# ...                ...                 ...         ...       ...          ...
# 46257       2019-04-29 2019-04-29 15:52:10         nan         2          4.2
# 46258       2019-04-29 2019-04-29 13:27:11         nan         2          4.2
# 46259       2019-04-29 2019-04-29 15:14:13      8107.0         1          2.1
# 46260       2019-04-29 2019-04-29 11:53:48      8431.0         2          6.0
# 46261       2019-04-29 2019-04-29 16:36:24      8401.0         1          2.1
#
# ...

# %%
query_coffee_gt1_cat = "product_category == 'Coffee' & quantity > 1"
df_coffee_sales.query(query_coffee_cat)
# Out:
#       transaction_date    transaction_time customer_id  quantity  retil_price  \
# 985         2019-04-01 2019-04-01 15:54:39       781.0         2          7.0
# 986         2019-04-01 2019-04-01 18:49:48       128.0         1          3.5
# 987         2019-04-01 2019-04-01 17:44:28       209.0         2          7.0
# 988         2019-04-01 2019-04-01 19:10:16       631.0         2          7.0
# 989         2019-04-01 2019-04-01 15:01:50       355.0         1          3.5
# ...                ...                 ...         ...       ...          ...
# 46257       2019-04-29 2019-04-29 15:52:10         nan         2          4.2
# 46258       2019-04-29 2019-04-29 13:27:11         nan         2          4.2
# 46259       2019-04-29 2019-04-29 15:14:13      8107.0         1          2.1
# 46260       2019-04-29 2019-04-29 11:53:48      8431.0         2          6.0
# 46261       2019-04-29 2019-04-29 16:36:24      8401.0         1          2.1
#
# ...

# %%
retil_price_mean = df_coffee_sales['retil_price'].mean()
query_retil_price_above_avg = "`retil_price` >"+str(retil_price_mean)
#query_retil_price_above_avg = "`retil_price` > `retil_price`.mean()"

df_coffee_sales.query(query_retil_price_above_avg)
# Out:
#       transaction_date    transaction_time customer_id  quantity  retil_price  \
# 2           2019-04-01 2019-04-01 12:05:31       659.0         2         5.00
# 4           2019-04-01 2019-04-01 19:17:34       537.0         2         5.00
# 5           2019-04-01 2019-04-01 17:58:05       385.0         2         5.00
# 7           2019-04-01 2019-04-01 11:40:26         7.0         2         5.00
# 9           2019-04-01 2019-04-01 11:14:45       212.0         2         5.00
# ...                ...                 ...         ...       ...          ...
# 49889       2019-04-24 2019-04-24 09:31:54      8113.0         1         8.95
# 49890       2019-04-25 2019-04-25 06:17:12      5778.0         1         8.95
# 49891       2019-04-25 2019-04-25 10:48:21         nan         1         8.95
# 49892       2019-04-25 2019-04-25 08:54:27      8039.0         1         8.95
# 49893       2019-04-25 2019-04-25 14:32:27      8081.0         1         8.95
#
# ...

# %%
df_coffee_sales['hour'] = df_coffee_sales['transaction_time'].dt.hour
df_coffee_sales[['transaction_time','hour']]
# Out:
#          transaction_time  hour
# 0     2019-04-01 12:04:43    12
# 1     2019-04-01 11:15:38    11
# 2     2019-04-01 12:05:31    12
# 3     2019-04-01 16:49:38    16
# 4     2019-04-01 19:17:34    19
# ...                   ...   ...
# 49889 2019-04-24 09:31:54     9
# 49890 2019-04-25 06:17:12     6
# 49891 2019-04-25 10:48:21    10
# 49892 2019-04-25 08:54:27     8
# 49893 2019-04-25 14:32:27    14
#
# [49894 rows x 2 columns]

# %%
df_coffee_sales['day_of_week']= df_coffee_sales['transaction_time'].dt.day_name()
df_coffee_sales['day_of_week']
# Out:
# 0           Monday
# 1           Monday
# 2           Monday
# 3           Monday
# 4           Monday
#            ...
# 49889    Wednesday
# 49890     Thursday
# 49891     Thursday
# 49892     Thursday
# 49893     Thursday
# Name: day_of_week, Length: 49894, dtype: object

# %%
df_coffee_sales['product_type'].value_counts()
df_coffee_sales['product_type'] = df_coffee_sales['product_type'].str.title()
df_coffee_sales['product_type']
# Out:
# 0        Brewed Chai Tea
# 1        Brewed Chai Tea
# 2        Brewed Chai Tea
# 3        Brewed Chai Tea
# 4        Brewed Chai Tea
#               ...
# 49889         Herbal Tea
# 49890         Herbal Tea
# 49891         Herbal Tea
# 49892         Herbal Tea
# 49893         Herbal Tea
# Name: product_type, Length: 49894, dtype: object

# %%
df_coffee_sales['product_type'].str.contains('Coffee')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49889    False
# 49890    False
# 49891    False
# 49892    False
# 49893    False
# Name: product_type, Length: 49894, dtype: bool

# %%
df_coffee_sales[df_coffee_sales['product_type'].str.contains('Coffee',case=False)]
# Out:
#       transaction_date    transaction_time customer_id  quantity  \
# 985         2019-04-01 2024-07-14 15:54:39       781.0         2
# 986         2019-04-01 2024-07-14 18:49:48       128.0         1
# 987         2019-04-01 2024-07-14 17:44:28       209.0         2
# 988         2019-04-01 2024-07-14 19:10:16       631.0         2
# 989         2019-04-01 2024-07-14 15:01:50       355.0         1
# ...                ...                 ...         ...       ...
# 39492       2019-04-29 2024-07-14 09:01:48      5042.0         2
# 39493       2019-04-29 2024-07-14 13:50:13      5747.0         1
# 39494       2019-04-29 2024-07-14 17:50:15         nan         2
# 39495       2019-04-29 2024-07-14 19:20:55         nan         2
# 39496       2019-04-29 2024-07-14 16:17:12      8344.0         1
#
#        line_item_amount  unit_price product_group product_category  \
# 985                7.00        3.50     Beverages           Coffee
# ...

# %%
def profit_cat(profit):
    if profit > 0:
        return 'profit'
    elif profit == 0:
        return ' breack even'
    else:
        return 'loss'

# %%
df_coffee_sales['product_category']= df_coffee_sales['profit'].apply(profit_cat)
df_coffee_sales[['profit','product_category']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[270], line 1
# ...

# %%
# Join df_all_orders with df_products
df_orders_products = pd.merge(df_all_orders, df_products, on='product_id', how='left')
# Join df_all_orders with df_regions
df_orders_regions = pd.merge(df_all_orders, df_regions, on='region_id', how='left')
# Join df_returns with df_products
df_returns_products = pd.merge(df_returns, df_products, on='product_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[257], line 2
#       1 # Join df_all_orders with df_products
# ----> 2 df_orders_products = pd.merge(df_all_orders, df_products, on='product_id', how='left')
#
# NameError: name 'df_all_orders' is not defined

# %%
# Join df_all_orders with df_regions
df_orders_regions = pd.merge(df_all_orders, df_regions, on='region_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[271], line 2
#       1 # Join df_all_orders with df_regions
# ----> 2 df_orders_regions = pd.merge(df_all_orders, df_regions, on='region_id', how='left')
#
# NameError: name 'df_all_orders' is not defined

# %%
# Join df_returns with df_products
df_returns_products = pd.merge(df_returns, df_products, on='product_id', how='left')
